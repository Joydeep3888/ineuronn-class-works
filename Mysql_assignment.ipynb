# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost', user='root', passwd='1234')

# %%
cursor=mydb.cursor()

mydb

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test_jg',),
#  ('world',)]

# %%
import csv
with open('glass.data', 'r') as f:
    glass_date=csv.reader(f, delimiter='\n')
    for i in glass_date:
        print('inserting', i[0])
        print(type(i[0]),type(str(i[0])))
        cursor.execute('insert into test_jg.glassdata values({values})'.format(values=i[0]))
mydb.commit()

# %%
import csv
with open('car.data', 'r+') as f:
    car_data=csv.reader(f, delimiter='\n')
    print(car_data)
    q="insert into test_jg.cardataset(buying,maint,doors,persons,lug_boot,safety,class) values (%s, %s, %s, %s, %s, %s, %s)"
    for i in car_data:
        print('inserted data', i[0])
        split=str(i[0]).split(",")
        cursor.execute(q,split)
# Out:
# ...
# inserted data vhigh,vhigh,2,2,small,low,unacc
# inserted data vhigh,vhigh,2,2,small,med,unacc
# inserted data vhigh,vhigh,2,2,small,high,unacc
# inserted data vhigh,vhigh,2,2,med,low,unacc
# inserted data vhigh,vhigh,2,2,med,med,unacc
# inserted data vhigh,vhigh,2,2,med,high,unacc
# inserted data vhigh,vhigh,2,2,big,low,unacc
# inserted data vhigh,vhigh,2,2,big,med,unacc
# inserted data vhigh,vhigh,2,2,big,high,unacc
# inserted data vhigh,vhigh,2,4,small,low,unacc
# inserted data vhigh,vhigh,2,4,small,med,unacc
# inserted data vhigh,vhigh,2,4,small,high,unacc
# inserted data vhigh,vhigh,2,4,med,low,unacc
# inserted data vhigh,vhigh,2,4,med,med,unacc
# inserted data vhigh,vhigh,2,4,med,high,unacc
# inserted data vhigh,vhigh,2,4,big,low,unacc
# inserted data vhigh,vhigh,2,4,big,med,unacc
# inserted data vhigh,vhigh,2,4,big,high,unacc
# inserted data vhigh,vhigh,2,more,small,low,unacc
# inserted data vhigh,vhigh,2,more,small,med,unacc
# inserted data vhigh,vhigh,2,more,small,high,unacc
# ...

# %%
cursor.execute('select * from test_jg.cardataset')

# %%
mydb.commit()

# %%
cursor.execute('select * from test_jg.cardataset')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '2', 'big', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'small', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'low', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'med', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'med', 'high', 'unacc'),
#  ('vhigh', 'vhigh', '2', '4', 'big', 'low', 'unacc'),
# ...

# %%
cursor.close()
# Out:
# False

# %%
import csv
with open('car.data', 'r+') as f:
    car_data=csv.reader(f, delimiter='\n')
    for i in car_data:
        print(str(i[0]))

# %%
cursor.execute('select * from test_jg.cardataset group by buying')

# %%
cursor.fetchall()
# Out:
# [(865, '2'), (864, '3'), (864, '4'), (864, '5more')]

# %%
cursor.execute('select * from test_jg.cardataset group by buying')

# %%
cursor.execute('select count(*),doors from test_jg.cardataset group by doors')

# %%
cursor.execute('select count(*),buying from test_jg.cardataset group by buying')

# %%
 # Create a new record
sql = "insert into test_jg.cardataset (buying,maint,doors,persons,lug_boot,safety,class) values (%s, %s, %s, %s, %s, %s, %s)"
cursor.execute(sql, ('vhigh','vhigh','2','2','small','low','unacc'))
# Execute query
sql = "SELECT * FROM test_jg.cardataset"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')

# %%
mydb.commit()

# %%
cursor.execute('SELECT * FROM test_jg.cardataset')

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc')]

# %%
a='Joydeep Ghosh'
x=a.split("G")
x
# Out:
# ['Joydeep ', 'hosh']
